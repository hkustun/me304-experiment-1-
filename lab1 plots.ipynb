# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
dfs = pd.read_excel("data1.xlsx")

# %% [markdown]
# PREPARING DATA

# %%
dfs.drop(0,inplace=True)
dfs.reset_index(drop=True, inplace=True)
dfs.columns = ['Input', 'O1_up', 'O1_down', 'O2_up','O2_down','O3_up','O3_down']
dfs
# Out:
#     Input  O1_up O1_down  O2_up O2_down  O3_up O3_down
# 0    0.70  0.176   0.185  0.177   0.181  0.183    0.18
# 1    0.75  0.182   0.189  0.183   0.189  0.187   0.187
# 2    0.80  0.187   0.194  0.185   0.194  0.191   0.192
# 3    0.85  0.193     0.2  0.192   0.201  0.199     0.2
# 4    0.90  0.199   0.208  0.202   0.207  0.204   0.205
# 5    0.95  0.205   0.214  0.209   0.213  0.211    0.21
# 6    1.00  0.214    0.22  0.218   0.219  0.217   0.219
# 7    1.05  0.219   0.227  0.226   0.227  0.224   0.225
# 8    1.10  0.224   0.234  0.232   0.234  0.229    0.23
# 9    1.15   0.23   0.239  0.238   0.239  0.235   0.238
# 10   1.20  0.237   0.245  0.246   0.245  0.242   0.243
# 11   1.25  0.243   0.252  0.252   0.251  0.248   0.251
# 12   1.30  0.253   0.258  0.258   0.258  0.257   0.255
# 13   1.35   0.26   0.266  0.262   0.263   0.26    0.26
# 14   1.40  0.267   0.271  0.272   0.271  0.267   0.268
# 15   1.45  0.273   0.276  0.275   0.277  0.273   0.273
# 16   1.50   0.28   0.281   0.28   0.282  0.279   0.281
# 17   1.55  0.286   0.288  0.291   0.289  0.288   0.287
# 18   1.60  0.295   0.295  0.294   0.295  0.293   0.293
# 19   1.65    0.3   0.302  0.298   0.301    0.3     0.3
# 20   1.70  0.307   0.309    0.3   0.307  0.307   0.306
# 21   1.75  0.316   0.316  0.306   0.314  0.315   0.313
# 22   1.80  0.321   0.323   0.32   0.321  0.323    0.32
# 23   1.85  0.327   0.331  0.328    0.33  0.328   0.325
# 24   1.90  0.334   0.338  0.332   0.338  0.334   0.338

# %% [markdown]
# CALCULATING AVERAGE VALUES

# %%
dfs["average_up"] = (dfs['O1_up'] + dfs['O2_up'] + dfs['O3_up']) / 3
dfs["average_down"] = (dfs['O1_down'] + dfs['O2_down'] + dfs['O3_down']) / 3
dfs["total_average"] = ((dfs['O1_up'] + dfs['O2_up'] + dfs['O3_up']) + (dfs['O1_down'] + dfs['O2_down'] + dfs['O3_down'])) / 6
dfs
# Out:
#     Input  O1_up O1_down  O2_up O2_down  O3_up O3_down average_up  \
# 0    0.70  0.176   0.185  0.177   0.181  0.183    0.18   0.178667
# 1    0.75  0.182   0.189  0.183   0.189  0.187   0.187      0.184
# 2    0.80  0.187   0.194  0.185   0.194  0.191   0.192   0.187667
# 3    0.85  0.193     0.2  0.192   0.201  0.199     0.2   0.194667
# 4    0.90  0.199   0.208  0.202   0.207  0.204   0.205   0.201667
# 5    0.95  0.205   0.214  0.209   0.213  0.211    0.21   0.208333
# 6    1.00  0.214    0.22  0.218   0.219  0.217   0.219   0.216333
# 7    1.05  0.219   0.227  0.226   0.227  0.224   0.225      0.223
# 8    1.10  0.224   0.234  0.232   0.234  0.229    0.23   0.228333
# 9    1.15   0.23   0.239  0.238   0.239  0.235   0.238   0.234333
# 10   1.20  0.237   0.245  0.246   0.245  0.242   0.243   0.241667
# 11   1.25  0.243   0.252  0.252   0.251  0.248   0.251   0.247667
# 12   1.30  0.253   0.258  0.258   0.258  0.257   0.255      0.256
# 13   1.35   0.26   0.266  0.262   0.263   0.26    0.26   0.260667
# 14   1.40  0.267   0.271  0.272   0.271  0.267   0.268   0.268667
# 15   1.45  0.273   0.276  0.275   0.277  0.273   0.273   0.273667
# 16   1.50   0.28   0.281   0.28   0.282  0.279   0.281   0.279667
# 17   1.55  0.286   0.288  0.291   0.289  0.288   0.287   0.288333
# 18   1.60  0.295   0.295  0.294   0.295  0.293   0.293      0.294
# 19   1.65    0.3   0.302  0.298   0.301    0.3     0.3   0.299333
# 20   1.70  0.307   0.309    0.3   0.307  0.307   0.306   0.304667
# 21   1.75  0.316   0.316  0.306   0.314  0.315   0.313   0.312333
# 22   1.80  0.321   0.323   0.32   0.321  0.323    0.32   0.321333
# 23   1.85  0.327   0.331  0.328    0.33  0.328   0.325   0.327667
# 24   1.90  0.334   0.338  0.332   0.338  0.334   0.338   0.333333
#
#    average_down total_average
# 0         0.182      0.180333
# 1      0.188333      0.186167
# 2      0.193333        0.1905
# 3      0.200333        0.1975
# 4      0.206667      0.204167
# 5      0.212333      0.210333
# 6      0.219333      0.217833
# 7      0.226333      0.224667
# 8      0.232667        0.2305
# 9      0.238667        0.2365
# 10     0.244333         0.243
# 11     0.251333        0.2495
# 12        0.257        0.2565
# 13        0.263      0.261833
# 14         0.27      0.269333
# 15     0.275333        0.2745
# 16     0.281333        0.2805
# 17        0.288      0.288167
# 18     0.294333      0.294167
# 19        0.301      0.300167
# 20     0.307333         0.306
# 21     0.314333      0.313333
# 22     0.321333      0.321333
# 23     0.328667      0.328167
# 24        0.338      0.335667

# %% [markdown]
# PLOTTING ALL THE DATA POINTS

# %%
plt.scatter(dfs["Input"], dfs["O1_up"], color='red', label='Cycle1_up',marker='o')
plt.scatter(dfs["Input"], dfs["O2_up"], color='red', label='Cycle2_up',marker='*')
plt.scatter(dfs["Input"], dfs["O3_up"], color='red', label='Cycle3_up',marker='^')

plt.scatter(dfs["Input"], dfs["O1_down"], color='blue', label='Cycle1_down',marker='o')
plt.scatter(dfs["Input"], dfs["O2_down"], color='blue', label='Cycle2_down',marker='*')
plt.scatter(dfs["Input"], dfs["O3_down"], color='blue', label='Cycle3_down',marker='^')
plt.xlabel('Input(mm)')
plt.ylabel('Output(kΩ)')
plt.legend()
plt.title("ALL POINTS")
plt.show()

# %% [markdown]
# AVERAGE CALCULATION PLOTS

# %%
plt.scatter(dfs["Input"], dfs["average_up"], label='average_up',marker='o')
plt.scatter(dfs["Input"], dfs["average_down"], label='average_down',marker='*')
plt.xlabel('Input(mm)')
plt.ylabel('Output(kΩ)')
plt.legend()
plt.title("AVERAGE UP-DOWN VALUES")
plt.show()

# %%
plt.scatter(dfs["Input"], dfs["total_average"], label='average')
plt.xlabel('Input(mm)')
plt.ylabel('Output(kΩ)')
plt.legend()
plt.title("AVERAGE VALUES")
plt.show()

# %% [markdown]
# CALCULATING LSL FROM AVERAGE POINTS

# %%
dfs["Input"] = pd.to_numeric(dfs["Input"])
dfs["total_average"] = pd.to_numeric(dfs["total_average"])
# Extract the input and measurement data from the DataFrame
input_data = dfs["Input"].values
measurement_data = dfs["total_average"].values

# Perform linear regression using numpy's polyfit
slope, intercept = np.polyfit(input_data, measurement_data, 1)

# Create the least squares line
line = slope * input_data + intercept

# Plot the data points and the least squares line
plt.scatter(input_data, dfs["average_up"], label='average_up')
plt.scatter(input_data, dfs["average_down"], label='average_down')
plt.plot(input_data, line, color='black', label='Least Squares Line')

# Add labels and legend
plt.xlabel('Input(mm)')
plt.ylabel('Output(kΩ)')
plt.title('Least Squares Line with average points')
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(dfs["Input"], dfs["O1_up"], color='red', label='Cycle1_up',marker='o')
plt.scatter(dfs["Input"], dfs["O2_up"], color='red', label='Cycle2_up',marker='*')
plt.scatter(dfs["Input"], dfs["O3_up"], color='red', label='Cycle3_up',marker='^')

plt.scatter(dfs["Input"], dfs["O1_down"], color='blue', label='Cycle1_down',marker='o')
plt.scatter(dfs["Input"], dfs["O2_down"], color='blue', label='Cycle2_down',marker='*')
plt.scatter(dfs["Input"], dfs["O3_down"], color='blue', label='Cycle3_down',marker='^')
plt.plot(input_data, line, color='black', label='Least Squares Line')

# Add labels and legend
plt.xlabel('Input(mm)')
plt.ylabel('Output(kΩ)')
plt.title('Least Squares Line with All Data')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# CALCULATING MAX DEVIATIONS

# %%
dfs["LSL"] = dfs["Input"] * slope + intercept
max_values = dfs[["O1_up", "O2_up", "O3_up", "O1_down", "O2_down", "O3_down"]].max(axis=1)
min_values = dfs[["O1_up", "O2_up", "O3_up", "O1_down", "O2_down", "O3_down"]].min(axis=1)
dfs["Max deviation from LSL"] = max_values - dfs["LSL"]
dfs["Min deviation from LSL"] = min_values - dfs["LSL"]
dfs["Max deviation from average"] = max_values - dfs["total_average"]
dfs["Min deviation from average"] = min_values - dfs["total_average"]
dfs
# Out:
#     Input  O1_up O1_down  O2_up O2_down  O3_up O3_down average_up  \
# 0    0.70  0.176   0.185  0.177   0.181  0.183    0.18   0.178667
# 1    0.75  0.182   0.189  0.183   0.189  0.187   0.187      0.184
# 2    0.80  0.187   0.194  0.185   0.194  0.191   0.192   0.187667
# 3    0.85  0.193     0.2  0.192   0.201  0.199     0.2   0.194667
# 2               -0.006605                     0.0035
# 3               -0.006047                     0.0035
# 4               -0.005489                   0.003833
# 5               -0.005931                   0.003667
# 6               -0.003374                   0.002167
# 7               -0.004816                   0.002333
# 8               -0.006258                     0.0035
# 9                 -0.0067                     0.0025
# 10              -0.006142                      0.003
# 11              -0.006584                     0.0025
# 12              -0.003027                     0.0015
# 13              -0.002469                   0.004167
# 14              -0.001911                   0.002667
# 15              -0.002353                     0.0025
# 16              -0.002795                     0.0015
# 17              -0.002238                   0.002833
# 18               -0.00168                   0.000833
# 19              -0.003122                   0.001833
# 20              -0.007564                      0.003
# 21              -0.008006                   0.002667
# 22              -0.000448                   0.001667
# 23              -0.001891                   0.002833
# 24              -0.001333                   0.002333
#
#    Min deviation from average
# 0                   -0.004333
# 1                   -0.004167
# 2                     -0.0055
# 3                     -0.0055
# 4                   -0.005167
# 5                   -0.005333
# 6                   -0.003833
# 7                   -0.005667
# 8                     -0.0065
# 9                     -0.0065
# 10                     -0.006
# 11                    -0.0065
# 12                    -0.0035
# 13                  -0.001833
# 14                  -0.002333
# 15                    -0.0015
# 16                    -0.0015
# 17                  -0.002167
# 18                  -0.001167
# 19                  -0.002167
# 20                     -0.006
# 21                  -0.007333
# 22                  -0.001333
# 23                  -0.003167
# 24                  -0.003667

# %% [markdown]
# DEVIATION PLOTS

# %%
plt.scatter(dfs["Input"], dfs["Max deviation from LSL"], label='max-deviation',marker='o')
plt.scatter(dfs["Input"], dfs["Min deviation from LSL"], label='min-deviation',marker='*')
plt.axhline(y=max(dfs["Max deviation from LSL"]), color='green', linestyle=':')
plt.axhline(y=min(dfs["Min deviation from LSL"]), color='green', linestyle=':')
plt.xlabel('Input(mm)')
plt.ylabel('Deviation(kΩ)')
plt.legend()
plt.title("DEVIATIONS FROM LSL")
plt.show()

# %%
plt.scatter(dfs["Input"], dfs["Max deviation from average"], label='max-deviation',marker='o')
plt.scatter(dfs["Input"], dfs["Min deviation from average"], label='min-deviation',marker='*')
plt.axhline(y=max(dfs["Max deviation from average"]), color='green', linestyle=':')
plt.axhline(y=min(dfs["Min deviation from average"]), color='green', linestyle=':')
plt.xlabel('Input(mm)')
plt.ylabel('Deviation(kΩ)')
plt.legend()
plt.title("DEVIATIONS FROM AVERAGE")
plt.show()

# %% [markdown]
# ACCURACY AND PRECISION ERROR PERCENTAGES

# %%
deviation_positive_accuracy = max(dfs["Max deviation from LSL"])
deviation_negative_accuracy = min(dfs["Min deviation from LSL"])
deviation_positive_precision = max(dfs["Max deviation from average"])
deviation_negative_precision = min(dfs["Min deviation from average"])
output_range = dfs.at[24,"LSL"] - dfs.at[0,"LSL"]
positive_accuracy_error = deviation_positive_accuracy / output_range * 100
negative_accuracy_error = abs(deviation_negative_accuracy) / output_range * 100
positive_precision_error = deviation_positive_precision / output_range * 100
negative_precision_error = abs(deviation_negative_precision) / output_range * 100
print("positive accuracy error percentage:",positive_accuracy_error)
print("negative accuracy error percentage as absolute value:",negative_accuracy_error)
print("positive precision error percentage:",positive_precision_error)
print("negative precision error percentage as absolute value:",negative_precision_error)
# Out:
# positive accuracy error percentage: 4.0614406920203505
# negative accuracy error percentage as absolute value: 5.178295422131131
# positive precision error percentage: 3.018302188434919
# negative precision error percentage as absolute value: 4.7430462961120465

# %% [markdown]
# REPEATABILITY AND HYSTERESIS CALCULATIONS

# %%
for index,row in dfs.iterrows(): #repeatability calculations 
    dfs.at[index,"repeatability"] = max((max(row[2],row[4],row[6]) - min(row[2],row[4],row[6])),(max(row[1],row[3],row[5]) - min(row[1],row[3],row[5])))

# %%
for index,row in dfs.iterrows(): #hysteresis calculations
    dfs.at[index,"hysteresis"] = max(abs(max(row[2],row[4],row[6]) - min(row[1],row[3],row[5])),abs(max(row[1],row[3],row[5])-min(row[2],row[4],row[6])))

# %% [markdown]
# HYSTERESIS AND REPEATABILITY ERROR CALCULATIONS

# %%
max_hysteresis = max(dfs["hysteresis"])
max_repeatability = max(dfs["repeatability"])
hysteresis_error = max_hysteresis/output_range * 100
repeatability_error = max_repeatability/output_range * 100
print("hysteresis error percentage:",hysteresis_error)
print("repeatability error percentage:",repeatability_error)
# Out:
# hysteresis error percentage: 6.467790403789138
# repeatability error percentage: 6.467790403789138

# %% [markdown]
# TERMINAL LINEARITY PLOTTING

# %%
x1,x2 = dfs.at[0,"Input"], dfs.at[24,"Input"]
y1,y2 = dfs.at[0,"total_average"], dfs.at[24,"total_average"]
slope2, intercept2 = np.polyfit([x1, x2], [y1, y2], 1)
input_data = dfs["Input"].values
line2 = slope2 * input_data + intercept2
plt.plot(input_data, line2, color='black', label='terminal line')
plt.scatter(dfs["Input"], dfs["total_average"], label='average',marker='*')

# Add labels and legend
plt.xlabel('Input(mm)')
plt.ylabel('Output(kΩ)')
plt.title('Terminal Line with Average Points')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# TERMINAL LINEARITY PERCENTAGE CALCULATION

# %%
dfs["terminal line value"] = line2
dfs["terminal linearity deviation"] = abs(dfs["total_average"] - dfs["terminal line value"])
max_deviation_from_terminal_line = max(dfs["terminal linearity deviation"])
terminal_linearity_error = max_deviation_from_terminal_line/output_range * 100
print("terminal linearity percentage:", terminal_linearity_error)
# Out:
# terminal linearity percentage: 2.4433874858759244

# %% [markdown]
# SENSITIVITY CALCULATIONS

# %%
input_range = dfs.at[24,"Input"] - dfs.at[0,"Input"] # units mm
output_range = dfs.at[24,"LSL"] - dfs.at[0,"LSL"] #units kΩ
sensitivity = output_range / input_range
print("sensitivity is:", sensitivity, "kΩ/mm")
# Out:
# sensitivity is: 0.1288435897435897 kΩ/mm

# %% [markdown]
# FINAL TABLE

# %%
dfs
# Out:
#     Input  O1_up O1_down  O2_up O2_down  O3_up O3_down average_up  \
# 0    0.70  0.176   0.185  0.177   0.181  0.183    0.18   0.178667
# 22     0.321333       0.321333  0.320448               0.002552
# 23     0.328667       0.328167  0.326891               0.004109
# 24        0.338       0.335667  0.333333               0.004667
#
#    Min deviation from LSL Max deviation from average  \
# 0               -0.002721                   0.004667
# 1               -0.003163                   0.002833
# 2               -0.006605                     0.0035
# 3               -0.006047                     0.0035
# 4               -0.005489                   0.003833
# 5               -0.005931                   0.003667
# 6               -0.003374                   0.002167
# 7               -0.004816                   0.002333
# 8               -0.006258                     0.0035
# 9                 -0.0067                     0.0025
# 10              -0.006142                      0.003
# 11              -0.006584                     0.0025
# 12              -0.003027                     0.0015
# 13              -0.002469                   0.004167
# 14              -0.001911                   0.002667
# 15              -0.002353                     0.0025
# 16              -0.002795                     0.0015
# 17              -0.002238                   0.002833
# 18               -0.00168                   0.000833
# 19              -0.003122                   0.001833
# 20              -0.007564                      0.003
# 21              -0.008006                   0.002667
# 22              -0.000448                   0.001667
# 23              -0.001891                   0.002833
# 24              -0.001333                   0.002333
#
#    Min deviation from average  repeatability  hysteresis  terminal line value  \
# 0                   -0.004333          0.007       0.009             0.180333
# 1                   -0.004167          0.005       0.007             0.186806
# 2                     -0.0055          0.006       0.009             0.193278
# 3                     -0.0055          0.007       0.009             0.199750
# 4                   -0.005167          0.005       0.009             0.206222
# 5                   -0.005333          0.006       0.009             0.212694
# 6                   -0.003833          0.004       0.006             0.219167
# 7                   -0.005667          0.007       0.008             0.225639
# 8                     -0.0065          0.008       0.010             0.232111
# 9                     -0.0065          0.008       0.009             0.238583
# 10                     -0.006          0.009       0.008             0.245056
# 11                    -0.0065          0.009       0.009             0.251528
# 12                    -0.0035          0.005       0.005             0.258000
# 13                  -0.001833          0.006       0.006             0.264472
# 14                  -0.002333          0.005       0.004             0.270944
# 15                    -0.0015          0.004       0.004             0.277417
# 16                    -0.0015          0.001       0.003             0.283889
# 17                  -0.002167          0.005       0.004             0.290361
# 18                  -0.001167          0.002       0.002             0.296833
# 19                  -0.002167          0.002       0.004             0.303306
# 20                     -0.006          0.007       0.009             0.309778
# 21                  -0.007333          0.010       0.010             0.316250
# 22                  -0.001333          0.003       0.003             0.322722
# 23                  -0.003167          0.006       0.004             0.329194
# 24                  -0.003667          0.002       0.006             0.335667
#
#     terminal linearity deviation
# 0                   2.775558e-17
# 1                   6.388889e-04
# 2                   2.777778e-03
# 3                   2.250000e-03
# 4                   2.055556e-03
# 5                   2.361111e-03
# 6                   1.333333e-03
# 7                   9.722222e-04
# 8                   1.611111e-03
# 9                   2.083333e-03
# 10                  2.055556e-03
# 11                  2.027778e-03
# 12                  1.500000e-03
# 13                  2.638889e-03
# 14                  1.611111e-03
# 15                  2.916667e-03
# 16                  3.388889e-03
# 17                  2.194444e-03
# 18                  2.666667e-03
# 19                  3.138889e-03
# 20                  3.777778e-03
# 21                  2.916667e-03
# 22                  1.388889e-03
# 23                  1.027778e-03
# 24                  0.000000e+00
